# %% [markdown]
# <a href="https://colab.research.google.com/github/nzungizelab/Gene_mapping/blob/NzungizeL/gene_mapping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install pygenomeviz

# %%
#load library
from pygenomeviz import GenomeViz

gv = GenomeViz()
track = gv.add_feature_track(name="AgamP4_X", size=39811767)

fig = gv.plotfig()  # or gv.savefig("test.png") or gv.savefig_html("test.html")

# %%
gv = GenomeViz(tick_style="axis")
track = gv.add_feature_track(name="AgamP4_3L", size=40000000, start_pos=39000000,labelsize=20, labelcolor='Black',)

#region = genomeviz.Region(size=41963435, start=39811767, end=39783924)

track.add_feature(start=39811767, end=39813716, strand=1, plotstyle="arrow", label="CYP9J3",labelsize=20,labelcolor="red",linewidth=20, labelvpos="top",)
track.add_feature(start=39814231, end=39816748, strand=1, plotstyle="arrow", label="CYP9J4")
track.add_feature(start=39817658, end=39818599, strand=1, plotstyle="arrow", label="CYP9L3")
#track.add_feature(start=39818918, end=39820604, strand=1, plotstyle="arrow", label="CYP9L2")
#track.add_feature(start=39820960, end=39822628, strand=1, plotstyle="arrow", label="CYP9L1", linewidth=1)
#track.add_feature(start=39836357, end=39838568, strand=1, plotstyle="arrow", label="CYP9J5")
#track.add_feature(start=39843265, end=39844535, strand=1, plotstyle="arrow", label="AGAP029290", linewidth=1)
#track.add_feature(start=39838657, end=39843009, strand=-1, plotstyle="arrow", label="AGAP029449")
#track.add_feature(start=39849612, end=39886884, strand=-1, plotstyle="arrow", label="AGAP029544", linewidth=1)
#track.add_feature(start=39780513, end=39783924, strand=-1, plotstyle="arrow", label="AGAP029548")

fig = gv.plotfig()

# %%
gv = GenomeViz(tick_style="axis")
track = gv.add_feature_track(name="AgamP4_3L", size=41963435)

track.add_feature(start=39811767, end=39813716, strand=1, plotstyle="arrow", label="CYP9J3", linewidth=1)
track.add_feature(start=39814231, end=39816748, strand=1, plotstyle="arrow", label="CYP9J4")
track.add_feature(start=39817658, end=39818599, strand=1, plotstyle="arrow", label="CYP9L3", linewidth=1)
track.add_feature(start=39818918, end=39820604, strand=1, plotstyle="arrow", label="CYP9L2")
track.add_feature(start=39820960, end=39822628, strand=1, plotstyle="arrow", label="CYP9L1", linewidth=1)
track.add_feature(start=39836357, end=39838568, strand=1, plotstyle="arrow", label="CYP9J5")
track.add_feature(start=39843265, end=39844535, strand=1, plotstyle="arrow", label="AGAP029290", linewidth=1)
track.add_feature(start=39838657, end=39843009, strand=-1, plotstyle="arrow", label="AGAP029449")
track.add_feature(start=39849612, end=39886884, strand=-1, plotstyle="arrow", label="AGAP029544", linewidth=1)
track.add_feature(start=39780513, end=39783924, strand=-1, plotstyle="arrow", label="AGAP029548")
#fig = gv.plotfig()
gv.savefig("cyp9j5.png")

# %%
from pygenomeviz import GenomeViz

name, genome_size = "CYP9J5", 41963435
cds_list = ((39811767, 39813716, -1), (39814231, 39816748, 1), (39817658, 39818599, 1), (39818918, 39820604, 1), (39820960, 39822628, -1), 
            (39836357, 39838568, 1), (39843265, 39844535, -1), (39838657, 39843009, -1), (39849612, 39886884, 1), (39780513, 39783924, -1))

gv = GenomeViz()
track = gv.add_feature_track(name, genome_size)
for idx, cds in enumerate(cds_list, 1):
    start, end, strand = cds
    #track.add_feature(start, end, strand, label=f"CDS{idx:02d}")

gv.savefig("example01.png")
# Out:
#   File "<ipython-input-36-cb8ebe7a2dcc>", line 12
#     track.add_feature(start, end, strand, label='cyp1','cyp2','cyp3','cyp4','cyp5','cyp6','cyp7','cyp8','cyp9','cyp10')
#                                                                                                                       ^
# SyntaxError: positional argument follows keyword argument

# %%
from pygenomeviz import GenomeViz

name, genome_size = "Tutorial 01", 5000
cds_list = ((100, 900, -1), (1100, 1300, 1), (1350, 1500, 1), (1520, 1700, 1), (1900, 2200, -1), (2500, 2700, 1), (2700, 2800, -1), (2850, 3000, -1), (3100, 3500, 1), (3600, 3800, -1), (3900, 4200, -1), (4300, 4700, -1), (4800, 4850, 1))

gv = GenomeViz()
track = gv.add_feature_track(name, genome_size)
for idx, cds in enumerate(cds_list, 1):
    start, end, strand = cds
    track.add_feature(start, end, strand, label=f"CDS{idx:02d}")

gv.savefig("example01.png")
